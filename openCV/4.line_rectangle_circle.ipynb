# %% [markdown]
# ## **Drawing images and shapes using OpenCV**
#
# Firsty, let's import OpenCV and numpy and define our imshow function

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# 이미지를 보여주는 함수 정의
def imshow(title = "image", image = None, size = 10):
  w, h = image.shape[0], image.shape[1]
  aspect_ration = w/h
  plt.figure(figsize = (size *aspect_ration,size))
  plt.imshow(cv2.cvtColor(image,cv2.COLOR_BGR2RGB))
  plt.title(title)
  plt.show()

# %%
#512x512짜리 빈 이미지를 만들자 
image = np.zeros((512,512,3), np.uint8)

# 검은색으로 만들자
image_gray = np.zeros((512,512), np.uint8)

#정의해둔 함수를 이용해 시각화
imshow("Black Canvas - RGB Color", image)
imshow("Black Canvas - Grayscale", image_gray)

# %% [markdown]
# ### **Drawing Rectangles**
# ```cv2.rectangle(image, starting vertex, opposite vertex, color, thickness)```

# %%
#직선을 그리자
cv2.line(image ,(0,0), (511,511), (255,127,0), 10) #(이미지, 시작점, 끝점, 색, 두께)

imshow("Black Canvas With Diagonal Line", image)

# %% [markdown]
# ### **Drawing Rectangles**
#
# ```cv2.rectangle(image, starting vertex, opposite vertex, color, thickness)```

# %%
# 빈 이미지를 다시 만들자(방금 이미지 위에 직선을 그렸으므로)
image = np.zeros((512,512,3),np.uint8)

# 사각형을 그리자 음수는 채우고 양수는 두께이다.
cv2.rectangle(image,(100,100), (300,250), (127,50,127), 10) #(이미지, 왼쪽위, 오른쪽아래, 색상, 두께)
imshow("Black Canvas With Pink Rectangle", image)

# %% [markdown]
# ### **Now let's draw some cirlcles?**
#
# ```cv2.cirlce(image, center, radius, color, fill)```

# %%
image = np.zeros((512,512,3), np.uint8)

cv2.circle(image, (350,350), 100, (15,150,50), -1) #(이미지 ,중심, 반지름 ,색상, 양수 두께, 음수 채워줘)
imshow("Black Canvas With Green Circle", image)

# %% [markdown]
# ### **Polygons**
#
# ```cv2.polylines(image, points, Closed?, color, thickness)```
#
# if Closed = True, we join the first and last points.

# %%
image = np.zeros((512,512,3), np.uint8)

# 네점을 정하자
pts = np.array([[0,1],[20,40],[90,40],[0,150]], np.int32)
print(pts)
# 만든 점을 직선으로 변경하자
pts = pts.reshape(-1,1,2)
print(pts)

cv2.polylines(image, [pts], True, (0,0,255), 3) #(이미지, 점, 닫혀있나, 색상, 두께)
imshow("Black Canvas with Red Polygon", image)
# Out:
# [[  0   1]
#  [ 20  40]
#  [ 90  40]
#  [  0 150]]
# [[[  0   1]]
#
#  [[ 20  40]]
#
#  [[ 90  40]]
#
#  [[  0 150]]]

# %%
pts = np.array( [[10,50], [400,50], [90,200], [50,500]], np.int32)
print(pts)
pts.shape
# Out:
# [[ 10  50]
#  [400  50]
#  [ 90 200]
#  [ 50 500]]
# (4, 2)

# %%
pts = pts.reshape((-1,1,2))
print(pts)
pts.shape
# Out:
# [[[ 10  50]]
#
#  [[400  50]]
#
#  [[ 90 200]]
#
#  [[ 50 500]]]
# (4, 1, 2)

# %% [markdown]
# ### **And now for adding text with cv2.putText**
#
# ```cv2.putText(image, 'Text to Display', bottom left starting point, Font, Font Size, Color, Thickness)```
#
# **Available Fonts**
# - FONT_HERSHEY_SIMPLEX, FONT_HERSHEY_PLAIN
# - FONT_HERSHEY_DUPLEX,FONT_HERSHEY_COMPLEX
# - FONT_HERSHEY_TRIPLEX, FONT_HERSHEY_COMPLEX_SMALL
# - FONT_HERSHEY_SCRIPT_SIMPLEX
# - FONT_HERSHEY_SCRIPT_COMPLEX

# %%
image = np.zeros((1000,1000,3), np.uint8)
ourString =  'Hello World!'
cv2.putText(image, ourString, (155,290), cv2.FONT_HERSHEY_SCRIPT_COMPLEX, 3, (40,200,0), 4)
imshow("Messing with some text", image)
